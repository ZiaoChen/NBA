# %% [markdown]
# # NBA API Exploration

# %% [markdown]
# ## Read Packages

# %%
from nba_api.stats.endpoints import commonplayerinfo
import pandas as pd
pd.describe_option('display')
# Out:
# display.chop_threshold : float or None
#     if set to a float value, all float values smaller then the given threshold
#     will be displayed as exactly 0 by repr and friends.
#     [default: None] [currently: None]
#
# display.colheader_justify : 'left'/'right'
#     Controls the justification of column headers. used by DataFrameFormatter.
#     [default: right] [currently: right]
#
# display.column_space No description available.
#     [default: 12] [currently: 12]
#
# display.date_dayfirst : boolean
#     When True, prints and parses dates with the day first, eg 20/01/2005
#     [default: False] [currently: False]
#
# display.date_yearfirst : boolean
#     When True, prints and parses dates with the year first, eg 2005/01/20
#     [default: False] [currently: False]
#
# display.encoding : str/unicode
#     Defaults to the detected encoding of the console.
#     Specifies the encoding to be used for strings returned by to_string,
# ...

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
pd.set_option('display.large_repr','truncate')

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 20;

# %% [markdown]
# ## Get Info on a Player

# %%
player_info = commonplayerinfo.CommonPlayerInfo(player_id=2544)

# %%
info = player_info.get_data_frames()

# %%
player_info.get_available_data()
# Out:
# dict_keys(['CommonPlayerInfo', 'PlayerHeadlineStats', 'AvailableSeasons'])

# %%
common_player_info = info[0]
common_player_info
# Out:
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0       2544     LeBron     James       LeBron James            James, LeBron
#
#   DISPLAY_FI_LAST            BIRTHDATE                        SCHOOL COUNTRY  \
# 0        L. James  1984-12-30T00:00:00  St. Vincent-St. Mary HS (OH)     USA
#
#                    LAST_AFFILIATION HEIGHT WEIGHT  SEASON_EXP JERSEY POSITION  \
# 0  St. Vincent-St. Mary HS (OH)/USA    6-8    250          15     23  Forward
#
#   ROSTERSTATUS     TEAM_ID TEAM_NAME TEAM_ABBREVIATION TEAM_CODE    TEAM_CITY  \
# 0       Active  1610612747    Lakers               LAL    lakers  Los Angeles
#
#      PLAYERCODE  FROM_YEAR  TO_YEAR DLEAGUE_FLAG NBA_FLAG GAMES_PLAYED_FLAG  \
# 0  lebron_james       2003     2018            N        Y                 Y
#
#   DRAFT_YEAR DRAFT_ROUND DRAFT_NUMBER
# 0       2003           1            1

# %%
player_headline_stats = info[1]
player_headline_stats
# Out:
#    PLAYER_ID   PLAYER_NAME TimeFrame   PTS  AST  REB    PIE
# 0       2544  LeBron James   2018-19  27.8  7.2  8.0  0.193

# %%
available_seasons = info[2]
available_seasons
# Out:
#    SEASON_ID
# 0      12003
# 1      22003
# 2      12004
# 3      22004
# 4      32004
# 5      12005
# 6      22005
# 7      32005
# 8      42005
# 9      12006
# 10     22006
# 11     32006
# 12     42006
# 13     12007
# 14     22007
# 15     32007
# 16     42007
# 17     12008
# 18     22008
# 19     32008
# 20     42008
# 21     12009
# 22     22009
# 23     32009
# 24     42009
# 25     12010
# 26     22010
# 27     32010
# 28     42010
# 29     12011
# 30     22011
# 31     32011
# 32     42011
# 33     12012
# 34     22012
# 35     32012
# 36     42012
# 37     12013
# 38     22013
# 39     32013
# 40     42013
# 41     12014
# 42     22014
# 43     32014
# 44     42014
# 45     12015
# 46     22015
# 47     32015
# 48     42015
# 49     12016
# 50     22016
# 51     32016
# 52     42016
# 53     12017
# 54     22017
# 55     32017
# 56     42017
# 57     12018
# 58     22018

# %% [markdown]
# ## Get All Players

# %%
from nba_api.stats.static import players

# %%
players.get_players()
# Out:
# [{'id': 76001,
#   'full_name': 'Alaa Abdelnaby',
#   'first_name': 'Alaa',
#   'last_name': 'Abdelnaby'},
#  {'id': 76002,
#   'full_name': 'Zaid Abdul-Aziz',
#   'first_name': 'Zaid',
#   'last_name': 'Abdul-Aziz'},
#  {'id': 76003,
#   'full_name': 'Kareem Abdul-Jabbar',
#   'first_name': 'Kareem',
#   'last_name': 'Abdul-Jabbar'},
#  {'id': 51,
#   'full_name': 'Mahmoud Abdul-Rauf',
#   'first_name': 'Mahmoud',
#   'last_name': 'Abdul-Rauf'},
#  {'id': 1505,
#   'full_name': 'Tariq Abdul-Wahad',
#   'first_name': 'Tariq',
#   'last_name': 'Abdul-Wahad'},
#  {'id': 949,
#   'full_name': 'Shareef Abdur-Rahim',
#   'first_name': 'Shareef',
#   'last_name': 'Abdur-Rahim'},
#  {'id': 76005,
#   'full_name': 'Tom Abernethy',
#   'first_name': 'Tom',
#   'last_name': 'Abernethy'},
#  {'id': 76006,
#   'full_name': 'Forest Able',
#   'first_name': 'Forest',
#   'last_name': 'Able'},
#  {'id': 76007,
#   'full_name': 'John Abramovic',
#   'first_name': 'John',
# ...

# %% [markdown]
# ## Find Player by Name

# %%
players.find_players_by_last_name('James')
# Out:
# [{'id': 77115,
#   'full_name': 'Aaron James',
#   'first_name': 'Aaron',
#   'last_name': 'James'},
#  {'id': 203108,
#   'full_name': 'Bernard James',
#   'first_name': 'Bernard',
#   'last_name': 'James'},
#  {'id': 202345,
#   'full_name': 'Damion James',
#   'first_name': 'Damion',
#   'last_name': 'James'},
#  {'id': 77116,
#   'full_name': 'Gene James',
#   'first_name': 'Gene',
#   'last_name': 'James'},
#  {'id': 1080,
#   'full_name': 'Henry James',
#   'first_name': 'Henry',
#   'last_name': 'James'},
#  {'id': 1744,
#   'full_name': 'Jerome James',
#   'first_name': 'Jerome',
#   'last_name': 'James'},
#  {'id': 2544,
#   'full_name': 'LeBron James',
#   'first_name': 'LeBron',
#   'last_name': 'James'},
#  {'id': 2229,
#   'full_name': 'Mike James',
#   'first_name': 'Mike',
#   'last_name': 'James'},
#  {'id': 1628455,
#   'full_name': 'Mike James',
#   'first_name': 'Mike',
#   'last_name': 'James'},
#  {'id': 1906,
#   'full_name': 'Tim James',
# ...

# %% [markdown]
# ## Find Teams

# %%
from nba_api.stats.static import teams

# %%
teams.get_teams()
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Atlanta',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966},
#  {'id': 1610612742,
# ...

# %%
teams.find_teams_by_full_name('clip')
# Out:
# [{'id': 1610612746,
#   'full_name': 'Los Angeles Clippers',
#   'abbreviation': 'LAC',
#   'nickname': 'Clippers',
#   'city': 'Los Angeles',
#   'state': 'California',
#   'year_founded': 1970}]

# %% [markdown]
# ## Get Games

# %% [markdown]
# ### Find all current season players

# %%
from nba_api.stats.endpoints import commonallplayers

# %%
all_current_players = commonallplayers.CommonAllPlayers(is_only_current_season=1,league_id='00',season='2018-19')

# %%
all_current_players.get_data_frames()[0]
# Out:
#      PERSON_ID   DISPLAY_LAST_COMMA_FIRST        DISPLAY_FIRST_LAST  \
# 0       203518              Abrines, Alex              Alex Abrines
# 1      1629121              Adams, Jaylen              Jaylen Adams
# 2       203500              Adams, Steven              Steven Adams
# 3      1628389               Adebayo, Bam               Bam Adebayo
# 4      1629152    Akoon-Purcell, DeVaughn    DeVaughn Akoon-Purcell
# 5       200746         Aldridge, LaMarcus         LaMarcus Aldridge
# 6      1628959              Alkins, Rawle              Rawle Alkins
# 7      1628960             Allen, Grayson             Grayson Allen
# 8      1628386             Allen, Jarrett             Jarrett Allen
# 9       202329           Aminu, Al-Farouq           Al-Farouq Aminu
# 10     1626147           Anderson, Justin           Justin Anderson
# 11      203937             Anderson, Kyle             Kyle Anderson
# 12      201583             Anderson, Ryan             Ryan Anderson
# ...

# %% [markdown]
# ### Find Games for a specific Date

# %%
from nba_api.stats.endpoints import scoreboard

# %%
data = scoreboard.Scoreboard(day_offset=0, league_id='00',game_date='2018-12-21')

# %%
data.get_available_data()
# Out:
# dict_keys(['GameHeader', 'LineScore', 'SeriesStandings', 'LastMeeting', 'EastConfStandingsByDay', 'WestConfStandingsByDay', 'Available'])

# %%
data.get_data_frames()[0]
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2018-12-21T00:00:00              1  0021800469               3
# 1  2018-12-21T00:00:00              2  0021800470               3
# 2  2018-12-21T00:00:00              3  0021800471               3
# 3  2018-12-21T00:00:00              4  0021800472               3
# 4  2018-12-21T00:00:00              5  0021800473               3
# 5  2018-12-21T00:00:00              6  0021800474               3
# 6  2018-12-21T00:00:00              7  0021800475               3
# 7  2018-12-21T00:00:00              8  0021800476               3
# 8  2018-12-21T00:00:00              9  0021800477               3
# 9  2018-12-21T00:00:00             10  0021800478               3
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0            Final  20181221/DETCHA    1610612766       1610612765   2018
# 1            Final  20181221/CLETOR    1610612761       1610612739   2018
# ...

# %%
teams.find_team_name_by_id(team_id='1610612766')
# Out:
# {'id': 1610612766,
#  'full_name': 'Charlotte Hornets',
#  'abbreviation': 'CHA',
#  'nickname': 'Hornets',
#  'city': 'Charlotte',
#  'state': 'North Carolina',
#  'year_founded': 1988}

# %%
teams.find_team_name_by_id(team_id='1610612765')
# Out:
# {'id': 1610612765,
#  'full_name': 'Detroit Pistons',
#  'abbreviation': 'DET',
#  'nickname': 'Pistons',
#  'city': 'Detroit',
#  'state': 'Michigan',
#  'year_founded': 1948}

# %% [markdown]
# ### Find Games Stats

# %%
from nba_api.stats.endpoints import boxscorescoringv2

# %%
data = boxscorescoringv2.BoxScoreScoringV2(game_id='0021800469')

# %%
data.get_available_data()
# Out:
# dict_keys(['sqlPlayersScoring', 'sqlTeamsScoring'])

# %%
data.get_data_frames()[0]
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0   0021800469  1610612765               DET    Detroit     203493
# 1   0021800469  1610612765               DET    Detroit     201933
# 2   0021800469  1610612765               DET    Detroit     203083
# 3   0021800469  1610612765               DET    Detroit    1628379
# 4   0021800469  1610612765               DET    Detroit     202704
# 5   0021800469  1610612765               DET    Detroit       2585
# 6   0021800469  1610612765               DET    Detroit     204038
# 7   0021800469  1610612765               DET    Detroit     101181
# 8   0021800469  1610612765               DET    Detroit    1626169
# 9   0021800469  1610612765               DET    Detroit    1628971
# 10  0021800469  1610612765               DET    Detroit     202720
# 11  0021800469  1610612765               DET    Detroit    1629017
# 12  0021800469  1610612766               CHA  Charlotte     201587
# ...

# %%
data.get_data_frames()[1]
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION  TEAM_CITY     MIN  \
# 0  0021800469  1610612765   Pistons               DET    Detroit  240:00
# 1  0021800469  1610612766   Hornets               CHA  Charlotte  240:00
#
#    PCT_FGA_2PT  PCT_FGA_3PT  PCT_PTS_2PT  PCT_PTS_2PT_MR  PCT_PTS_3PT  \
# 0        0.585        0.415        0.558           0.023        0.279
# 1        0.680        0.320        0.429           0.020        0.367
#
#    PCT_PTS_FB  PCT_PTS_FT  PCT_PTS_OFF_TOV  PCT_PTS_PAINT  PCT_AST_2PM  \
# 0       0.047       0.163            0.081          0.535        0.542
# 1       0.102       0.204            0.173          0.408        0.571
#
#    PCT_UAST_2PM  PCT_AST_3PM  PCT_UAST_3PM  PCT_AST_FGM  PCT_UAST_FGM
# 0         0.458        1.000         0.000        0.656         0.344
# 1         0.429        0.583         0.417        0.576         0.424

# %% [markdown]
# ### More Exploration on Game Stats

# %%
from nba_api.stats.endpoints import boxscoresummaryv2

# %%
data = boxscoresummaryv2.BoxScoreSummaryV2(game_id='0021800469')

# %%
data.get_available_data()
# Out:
# dict_keys(['GameSummary', 'OtherStats', 'Officials', 'InactivePlayers', 'GameInfo', 'LineScore', 'LastMeeting', 'SeasonSeries', 'AvailableVideo'])

# %% [markdown]
# #### Game Summary (Game Status)

# %%
data.get_data_frames()[0]
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2018-12-21T00:00:00              1  0021800469               3
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0            Final  20181221/DETCHA    1610612766       1610612765   2018
#
#    LIVE_PERIOD LIVE_PC_TIME NATL_TV_BROADCASTER_ABBREVIATION  \
# 0            4                                          None
#
#   LIVE_PERIOD_TIME_BCAST  WH_STATUS
# 0            Q4       -           1

# %% [markdown]
# #### Other Stats (Team Stats)

# %%
data.get_data_frames()[1]
# Out:
#   LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PTS_PAINT  \
# 0        00  1610612765               DET    Detroit         46
# 1        00  1610612766               CHA  Charlotte         40
#
#    PTS_2ND_CHANCE  PTS_FB  LARGEST_LEAD  LEAD_CHANGES  TIMES_TIED  \
# 0               7       4             2             3           4
# 1               7      10            15             3           4
#
#    TEAM_TURNOVERS  TOTAL_TURNOVERS  TEAM_REBOUNDS  PTS_OFF_TO
# 0               2               16              7          17
# 1               2               18             17           7

# %% [markdown]
# #### Officials (Referee)

# %%
data.get_data_frames()[2]
# Out:
#    OFFICIAL_ID FIRST_NAME LAST_NAME JERSEY_NUM
# 0         2003        Pat    Fraher       26
# 1       202041      Kevin     Scott       28
# 2       202901       Matt     Myers       43

# %% [markdown]
# #### Inactive Players

# %%
data.get_data_frames()[3]
# Out:
#    PLAYER_ID FIRST_NAME     LAST_NAME JERSEY_NUM     TEAM_ID  TEAM_CITY  \
# 0     202687    Bismack       Biyombo       8     1610612766  Charlotte
# 1    1629147        Joe       Chealey       31    1610612766  Charlotte
# 2    1629122       J.P.        Macura       55    1610612766  Charlotte
# 3    1627740      Henry      Ellenson       8     1610612765    Detroit
# 4    1629037     Keenan         Evans       12    1610612765    Detroit
# 5     202397        Ish         Smith       14    1610612765    Detroit
# 6    1629155       Zach        Lofton       18    1610612765    Detroit
# 7     203922      Glenn  Robinson III       22    1610612765    Detroit
#
#   TEAM_NAME TEAM_ABBREVIATION
# 0   Hornets               CHA
# 1   Hornets               CHA
# 2   Hornets               CHA
# 3   Pistons               DET
# 4   Pistons               DET
# 5   Pistons               DET
# 6   Pistons               DET
# 7   Pistons               DET

# %% [markdown]
# #### Game Info (Attendence, Time)

# %%
data.get_data_frames()[4]
# Out:
#                    GAME_DATE  ATTENDANCE GAME_TIME
# 0  FRIDAY, DECEMBER 21, 2018       15812      2:15

# %% [markdown]
# #### Line Score (Quarter Score)

# %%
data.get_data_frames()[5]
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID     TEAM_ID  \
# 0  2018-12-21T00:00:00              1  0021800469  1610612766
# 1  2018-12-21T00:00:00              1  0021800469  1610612765
#
#   TEAM_ABBREVIATION TEAM_CITY_NAME TEAM_NICKNAME TEAM_WINS_LOSSES  PTS_QTR1  \
# 0               CHA      Charlotte       Hornets            16-15        25
# 1               DET        Detroit       Pistons            15-15        21
#
#    PTS_QTR2  PTS_QTR3  PTS_QTR4  PTS_OT1  PTS_OT2  PTS_OT3  PTS_OT4  PTS_OT5  \
# 0        20        30        23        0        0        0        0        0
# 1        19        25        21        0        0        0        0        0
#
#    PTS_OT6  PTS_OT7  PTS_OT8  PTS_OT9  PTS_OT10  PTS
# 0        0        0        0        0         0   98
# 1        0        0        0        0         0   86

# %% [markdown]
# #### LastMeeting (Last Game)

# %%
data.get_data_frames()[6]
# Out:
#       GAME_ID LAST_GAME_ID   LAST_GAME_DATE_EST  LAST_GAME_HOME_TEAM_ID  \
# 0  0021800469   0021800405  2018-12-12T00:00:00              1610612766
#
#   LAST_GAME_HOME_TEAM_CITY LAST_GAME_HOME_TEAM_NAME  \
# 0                Charlotte                  Hornets
#
#   LAST_GAME_HOME_TEAM_ABBREVIATION  LAST_GAME_HOME_TEAM_POINTS  \
# 0                              CHA                         108
#
#    LAST_GAME_VISITOR_TEAM_ID LAST_GAME_VISITOR_TEAM_CITY  \
# 0                 1610612765                     Detroit
#
#   LAST_GAME_VISITOR_TEAM_NAME LAST_GAME_VISITOR_TEAM_CITY1  \
# 0                     Pistons                          DET
#
#    LAST_GAME_VISITOR_TEAM_POINTS
# 0                            107

# %% [markdown]
# #### Season On Series (Previous game stats)

# %%
data.get_data_frames()[7]
# Out:
#       GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID        GAME_DATE_EST  \
# 0  0021800469    1610612766       1610612765  2018-12-21T00:00:00
#
#    HOME_TEAM_WINS  HOME_TEAM_LOSSES SERIES_LEADER
# 0               3                 0     Charlotte

# %% [markdown]
# #### Available Videos

# %%
data.get_data_frames()[8]
# Out:
#       GAME_ID  VIDEO_AVAILABLE_FLAG  PT_AVAILABLE  PT_XYZ_AVAILABLE  \
# 0  0021800469                     1             1                 0
#
#    WH_STATUS  HUSTLE_STATUS  HISTORICAL_STATUS
# 0          1              1                  0
